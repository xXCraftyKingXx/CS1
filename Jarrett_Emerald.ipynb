# %% [markdown]
# <a href="https://colab.research.google.com/github/xXCraftyKingXx/CS1/blob/main/Jarrett_Emerald.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ( "Hello me, myself, and I")
# Out:
# Hello me, myself, and I
